# %% [markdown]
# #### Check paths

# %%
from utils import gspread_obj
from config import credentials_google, gspread_url   #get google API credentials
from feather import read_dataframe, write_dataframe

# %load_ext rpy2.ipython
# !pwd
# Out:
# /Users/yensia-low/PycharmProjects/nCoV2019/notebooks

# %% [markdown]
# ## Get data

# %%
gc = gspread_obj()
gc.login(credentials_google)
gc.get_sheets(gspread_url)
df = gc.merge_sheets()
df.sort_values(['date_confirmation', 'country', 'city', 'ID'], axis=0, ascending=True, inplace=True)
df.head()
# Out:
# Columns:  Index(['ID', 'age', 'sex', 'city', 'province', 'country',
#        'wuhan(0)_not_wuhan(1)', 'latitude', 'longitude', 'geo_resolution',
#        'date_onset_symptoms', 'date_admission_hospital', 'date_confirmation',
#        'symptoms', 'lives_in_Wuhan', 'travel_history_dates',
#        'travel_history_location', 'reported_market_exposure',
#        'additional_information', 'chronic_disease_binary', 'chronic_disease',
#        'source', 'sequence_available', 'outcome', 'date_death_or_discharge',
#        'notes_for_discussion', 'location', 'admin3', 'admin2', 'admin1',
#        'country_new', 'admin_id', 'data_moderator_initials'],
#       dtype='object')
# 15604 Rows x 33 Columns
#         ID    age     sex     city  province country wuhan(0)_not_wuhan(1)  \
# 7661  7886                                                               1
# 1460  1465  50-59  female  Toronto   Ontario  Canada                     1
# ...

# %%
"^$|^\d{2}[.-]\d{2}[.-]\d{4}$"

x = df.date_confirmation
x
# Out:
# 7661
# 1460
# 281
# 282
# 283
#            ...
# 3223    31.01.2020
# 3224    31.01.2020
# 4851    31.01.2020
# 32        not sure
# 33        not sure
# Name: date_confirmation, Length: 15604, dtype: object

# %%
# %%R -i x
# .date_regex_check <- function(x) grepl(pattern = "(^$|^[0-9]{2}\\.[0-9]{2}\\.[0-9]{4}$|^[0-9]{2}\\.[0-9]{2}\\.[0-9]{4}-[0-9]{2}\\.[0-9]{2}\\.[0-9]{4}$|-[0-9]{2}\\.[0-9]{2}\\.[0-9]{4}$|^[0-9]{2}\\.[0-9]{2}\\.[0-9]{4}-$)", x = x)
# .date_regex_check(x)
# Out:
#     [1]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#    [13]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#    [25]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#    [37]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#    [49]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#    [61]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#    [73]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#    [85]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#    [97]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#   [109]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#   [121]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
#   [133]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
# ...

# %% [markdown]
# #### Set schema

# %%
df.infer_objects()
# Out:
#         ID  age     sex                  city   province         country  \
# 1460  1465  50s  female               Toronto    Ontario          Canada
# 281    286         male                         Shanghai           China
# 282    287         male                         Shanghai           China
# 283    288         male                         Shanghai           China
# 284    289       female                         Shanghai           China
# ...    ...  ...     ...                   ...        ...             ...
# 3223  3228                          Newcastle             United Kingdom
# 3224  3229                          Newcastle             United Kingdom
# 4863  4868   25  female  Hotel Ton Dan Street  Nha Trang         Vietnam
# 32      33   32    male                 Wuhan      Hubei           China
# 33      34   49  female                 Wuhan      Hubei           China
#
#      wuhan(0)_not_wuhan(1)   latitude   longitude geo_resolution  ...  \
# ...

# %%
df.dtypes
# Out:
# ID                          object
# age                         object
# sex                         object
# city                        object
# province                    object
# country                     object
# wuhan(0)_not_wuhan(1)       object
# latitude                    object
# longitude                   object
# geo_resolution              object
# date_onset_symptoms         object
# date_admission_hospital     object
# date_confirmation           object
# symptoms                    object
# lives_in_Wuhan              object
# travel_history_dates        object
# travel_history_location     object
# reported_market_exposure    object
# additional_information      object
# chronic_disease_binary      object
# chronic_disease             object
# source                      object
# sequence_available          object
# outcome                     object
# date_death_or_discharge     object
# notes_for_discussion        object
# location                    object
# ...

# %%
col_date = list(filter(lambda x:'date' in x, df.columns))
col_date
# Out:
# ['date_onset_symptoms',
#  'date_admission_hospital',
#  'date_confirmation',
#  'travel_history_dates',
#  'date_death_or_discharge']

# %%
col_int = ['ID','age']
col_float = ['latitude','longitude']
col_bin = ['sex','wuhan(0)_not_wuhan(1)','chronic_disease_binary']
col_cat = ['city','province','country','geo_resolution','location','lives_in_Wuhan',
           'outcome','reported_market_exposure','sequence_available']
col_text = ['chronic_disease','symptoms',
            'travel_history_location','source',
            'notes_for_discussion','additional_information']

# %%
df.age.value_counts()
# Out:
#          14400
# N/A        217
# 15-88       58
# 50-59       44
# 25-89       37
#          ...
# 79           1
# 84           1
# 83           1
# 80-89        1
# 3            1
# Name: age, Length: 105, dtype: int64

# %%
df.age[df.age.str.contains('\D', regex=True)].value_counts()
# Out:
# N/A        217
# 15-88       58
# 50-59       44
# 25-89       37
# 23-72       35
# 16-80       34
# 40-49       32
# NA          30
# 60-69       25
# 70-82       15
# 21-39       10
# 20-29        6
# 30-39        6
# 36-45        5
# 20s          2
# 0.58333      1
# 80-89        1
# 0.08333      1
# 38-68        1
# Name: age, dtype: int64

# %%
df.latitude[~(df.latitude.str.contains('\d|\.', case=False, regex=True))]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-92-c5881b306a83> in <module>
# ----> 1 df.latitude[~(df.latitude.str.contains('\d|\.', case=False, regex=True))]=NaN
#
# NameError: name 'NaN' is not defined

# %%
df.latitude.filter(regex='^\d+.\d+$')x
# Out:
# 1460    43.667256
# 281     31.138278
# 282     31.138278
# 283     31.138278
# 284     31.138278
#           ...
# 4112    15
# 4113    15
# 3223    54.966667
# 3224    54.966667
# 4863
# Name: latitude, Length: 13193, dtype: object

# %%
df[col_float].apply(lambda x: x.astype('float'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-9dbc5e3bd0f5> in <module>
# ----> 1 df[col_float].apply(lambda x: x.astype('float'))
#
# ~/venv/tfenv/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6926             kwds=kwds,
#    6927         )
# -> 6928         return op.get_result()
#    6929
#    6930     def applymap(self, func):
#
# ~/venv/tfenv/lib/python3.6/site-packages/pandas/core/apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# ~/venv/tfenv/lib/python3.6/site-packages/pandas/core/apply.py in apply_standard(self)
#     290
#     291         # compute the result using the series generator
# ...

# %%
df[col_int].apply(lambda x: x.astype('int32'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-05ebf6d4f2c5> in <module>
# ----> 1 df[col_int].apply(lambda x: x.astype('int32'))
#
# ~/venv/tfenv/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6926             kwds=kwds,
#    6927         )
# -> 6928         return op.get_result()
#    6929
#    6930     def applymap(self, func):
#
# ~/venv/tfenv/lib/python3.6/site-packages/pandas/core/apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# ~/venv/tfenv/lib/python3.6/site-packages/pandas/core/apply.py in apply_standard(self)
#     290
#     291         # compute the result using the series generator
# ...

# %% [markdown]
# #### Data validation with tfdv

# %%
import tensorflow_data_validation as tfdv
print('TFDV version: {}'.format(tfdv.version.__version__))
print(tfdv.StatsOptions)
# Out:
# TFDV version: 0.21.0
# <class 'tensorflow_data_validation.statistics.stats_options.StatsOptions'>

# %%
summary_stats = tfdv.generate_statistics_from_dataframe(df)
# Out:
# /Users/yensia-low/venv/tfenv/lib/python3.6/site-packages/tensorflow_data_validation/arrow/arrow_util.py:214: FutureWarning: Calling .data on ChunkedArray is provided for compatibility after Column was removed, simply drop this attribute
#   types.FeaturePath([column_name]), column.data.chunk(0), weights):

# %%
tfdv.visualize_statistics(summary_stats)
# Out:
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %%
schema = tfdv.infer_schema(summary_stats)
tfdv.display_schema(schema)
# Out:
#                               Type  Presence Valency  \
# Feature name
# 'ID'                         BYTES  required
# 'additional_information'     BYTES  required
# 'age'                        BYTES  required
# 'chronic_disease'           STRING  required
# 'chronic_disease_binary'    STRING  required
# 'city'                       BYTES  required
# 'country'                   STRING  required
# 'date_admission_hospital'   STRING  required
# 'date_confirmation'         STRING  required
# 'date_death_or_discharge'   STRING  required
# 'date_onset_symptoms'       STRING  required
# 'geo_resolution'            STRING  required
# 'latitude'                   BYTES  required
# 'lives_in_Wuhan'            STRING  required
# 'location'                  STRING  optional  single
# 'longitude'                  BYTES  required
# 'notes_for_discussion'      STRING  required
# 'outcome'                   STRING  required
# 'province'                  STRING  required
# ...
